# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/My Drive/Heart_Disease/heart.csv')
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df['Age'].unique()
# Out:
# array([40, 49, 37, 48, 54, 39, 45, 58, 42, 38, 43, 60, 36, 44, 53, 52, 51,
#        56, 41, 32, 65, 35, 59, 50, 47, 31, 46, 57, 55, 63, 66, 34, 33, 61,
#        29, 62, 28, 30, 74, 68, 72, 64, 69, 67, 73, 70, 77, 75, 76, 71])

# %%
df['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df['RestingBP'].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164])

# %%
#Remove Outliers from RestingBP
df1=df[(df['RestingBP']>=50) & (df['RestingBP']<=260)]

# %%
df1['RestingBP'].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123, 102,
#         96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192, 129,
#        164])

# %%
df1['Cholesterol'].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 263, 291, 229, 307, 210, 329, 147,  85,
#        269, 275, 179, 392, 466, 129, 241, 255, 276, 282, 338, 160, 156,
#        272, 240, 393, 161, 228, 292, 388, 166, 247, 331, 341, 243, 279,
#        198, 249, 168, 603, 159, 190, 185, 290, 212, 231, 222, 235, 320,
#        187, 266, 287, 404, 312, 251, 328, 285, 280, 192, 193, 308, 219,
#        257, 132, 226, 217, 303, 298, 256, 117, 295, 173, 315, 281, 309,
#        200, 336, 355, 326, 171, 491, 271, 274, 394, 221, 126, 305, 220,
#        242, 347, 344, 358, 169, 181,   0, 236, 203, 153, 316, 311, 252,
# ...

# %%
df1=df1[(df1['Cholesterol']>=60)&(df1['Cholesterol']<=600)]

# %%
df1['Cholesterol'].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 263, 291, 229, 307, 210, 329, 147,  85,
#        269, 275, 179, 392, 466, 129, 241, 255, 276, 282, 338, 160, 156,
#        272, 240, 393, 161, 228, 292, 388, 166, 247, 331, 341, 243, 279,
#        198, 249, 168, 159, 190, 185, 290, 212, 231, 222, 235, 320, 187,
#        266, 287, 404, 312, 251, 328, 285, 280, 192, 193, 308, 219, 257,
#        132, 226, 217, 303, 298, 256, 117, 295, 173, 315, 281, 309, 200,
#        336, 355, 326, 171, 491, 271, 274, 394, 221, 126, 305, 220, 242,
#        347, 344, 358, 169, 181, 236, 203, 153, 316, 311, 252, 458, 384,
# ...

# %%
# Check there is any outliers in MaxHR

max_HR=df1[(df1['MaxHR']<60) | (df1['MaxHR']>202)]
max_HR
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
#Check Outliers
oldpeak=df1[(df1['Oldpeak']<0.0) | (df1['Oldpeak']>4)]
oldpeak
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 512   35   M           NAP        123          161          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 512    153              N     -0.1       Up             0
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# ...

# %%
#Remove Outliers
df1=df1[(df1['Oldpeak']>0.0) & (df1['Oldpeak']<5)]

# %%
oldpeak=df1[(df1['Oldpeak']<0.0) | (df1['Oldpeak']>=5)]
oldpeak
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df1.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df1.shape
# Out:
# (424, 12)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x=df1.drop(columns='HeartDisease')
y=df1['HeartDisease']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_cols=['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope']

preprocess=ColumnTransformer(
    transformers=[
        ('cat',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),categorical_cols)
    ],
)

x_train_enc = preprocess.fit_transform(x_train)
x_test_enc  = preprocess.transform(x_test)

# %%
from sklearn.metrics import accuracy_score

lr=LogisticRegression()
lr.fit(x_train_enc,y_train)
y_pred=lr.predict(x_test_enc)
#lr.score(x_test_enc,y_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8588235294117647

# %%
from sklearn.tree import DecisionTreeClassifier

DT=DecisionTreeClassifier()
DT.fit(x_train_enc,y_train)
DT.score(x_test_enc,y_test)
# Out:
# 0.8

# %%
def get_result(age,sex,ChestPain,restingBP,Cholesterol,FastingBS,RestingECG,MaxHR,exerciseAnginea,oldPeak,stSlope):
  input=pd.DataFrame([{
      'Age':age,
      'Sex':sex,
      'ChestPainType':ChestPain,
      'RestingBP':restingBP,
      'Cholesterol':Cholesterol,
      'FastingBS':FastingBS,
      'RestingECG':RestingECG,
      'MaxHR':MaxHR,
      'ExerciseAngina':exerciseAnginea,
      'OldPeak':oldPeak,
      'ST_Slope':stSlope
  }])

  input_encoded=preprocess.transform(input)
  prdiction=lr.predict(input_encoded)[0]
  return prdiction

# %%
get_result(45,"M","ATA",130,220,0,"Normal",150,"N",1.2,"Up")
# Out:
# np.int64(0)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cf=confusion_matrix(y_pred,y_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cf)
disp.plot(cmap='Blues')

plt.title("Confusion Matrix")
plt.show()

# %%
import pickle

pkl_path="/content/drive/My Drive/Heart_Disease/Heart_Diseases.pkl"

artifcats={
    'preprocess':preprocess,
    'model':lr
}

with open(pkl_path,'wb') as f:
  pickle.dump(artifcats,f)
